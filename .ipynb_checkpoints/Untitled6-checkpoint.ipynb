# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
dataset_train=pd.read_csv('PM_train.txt',sep=' ',header=None).drop([26,27],axis=1)
col_names = ['id','cycle','setting1','setting2','setting3','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10','s11','s12','s13','s14','s15','s16','s17','s18','s19','s20','s21']
dataset_train.columns=col_names
print('Shape of Train dataset: ',dataset_train.shape)
dataset_train.head()
# Out:
# Shape of Train dataset:  (20631, 26)
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0
#
#      s20      s21
# ...

# %%
dataset_train['ttf'] = dataset_train.groupby(['id'])['cycle'].transform(max)-dataset_train['cycle']
dataset_train.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s13      s14     s15   s16  s17   s18    s19    s20  \
# 0  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06
# 1  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00
# 2  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95
# 3  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88
# 4  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90
#
#        s21  ttf
# 0  23.4190  191
# 1  23.4236  190
# 2  23.3442  189
# ...

# %%
dataset_train['label1'] = dataset_train.groupby(['id'])['cycle'].transform(max)-dataset_train['cycle']
dataset_train.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s14     s15   s16  s17   s18    s19    s20      s21  ttf  \
# 0  14.62  ...  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190  191
# 1  14.62  ...  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236  190
# 2  14.62  ...  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442  189
# 3  14.62  ...  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739  188
# 4  14.62  ...  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044  187
#
#    label1
# 0     191
# 1     190
# 2     189
# ...

# %%
for i in range(20631):
    if dataset_train.at[i, 'label1'] > 29:
        dataset_train.at[i, 'label1'] = 0
    elif dataset_train.at[i, 'label1'] <= 29 and dataset_train.at[i, 'label1'] >14 :
        dataset_train.at[i, 'label1'] = 1
    else:
        dataset_train.at[i, 'label1'] = 2

# %%
# 説明変数
X_multi = dataset_train.drop(['cycle','label1','ttf'],1)

# 目的変数
Y_target = dataset_train.label1

# %%
X_multi.head()
# Out:
#    id  setting1  setting2  setting3      s1      s2       s3       s4     s5  \
# 0   1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60  14.62
# 1   1    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14  14.62
# 2   1   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20  14.62
# 3   1    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87  14.62
# 4   1   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22  14.62
#
#       s6  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  21.61  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0
# 1  21.61  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0
# 2  21.61  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0
# 3  21.61  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0
# 4  21.61  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0
#
#      s20      s21
# 0  39.06  23.4190
# 1  39.00  23.4236
# ...

# %%
Y_target.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label1, dtype: int64

# %%
import sklearn
from sklearn.linear_model import LogisticRegression

# %%
# LogisticRegressionクラスのインスタンスを作ります。
log_model = LogisticRegression() # fit_intercept=False, C=1e9) statsmodelsの結果に似せるためのパラメータ。

# データを使って、モデルを作ります。
log_model.fit(X_multi,Y_target)

# モデルの精度を確認してみましょう。
log_model.score(X_multi,Y_target)
# Out:
# C:\Users\tomoy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tomoy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.9128011245213513

# %%
from sklearn.model_selection import train_test_split

# 精度を計算するのに便利なツールです。
from sklearn import metrics

# おなじく、train_test_splitを使う
X_train, X_test, Y_train, Y_test = train_test_split(X_multi, Y_target, test_size=0.3)

# 新しいモデルを作る
log_model2 = LogisticRegression()

# 学習用のデータだけでモデルを鍛える
log_model2.fit(X_train, Y_train)

# データを使って学習
logreg.fit(X_train, Y_train)

# テストデータを予測
Y_pred = logreg.predict(X_test)

# .scoreで正解率を算出。
print("train score:",log_model2.score(X_train,Y_train))
print("test score:",log_model2.score(X_test,Y_test))
# Out:
# C:\Users\tomoy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tomoy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\tomoy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tomoy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# train score: 0.9153798213420123
# test score: 0.9054927302100162

# %%
log_model.coef_
# Out:
# array([[ 4.06215045e-03, -2.58081189e-05, -1.13475454e-06,
#          4.83166153e-03,  2.50603789e-02, -3.16941664e-02,
#         -1.52778250e-01, -2.75522465e-01,  7.06388916e-04,
#          1.04026381e-03,  1.43774431e-01,  1.05399084e-01,
#         -7.19359256e-02,  6.28115999e-05, -3.62897159e-02,
#          1.25858999e-01,  1.05450525e-01,  5.26899762e-02,
#         -4.42081545e-03,  1.44949846e-06, -1.49167065e-01,
#          1.15380077e-01,  4.83166153e-03,  2.35893446e-02,
#          1.48919230e-02],
#        [-1.69353556e-03,  1.11870608e-04,  6.46919992e-06,
#         -1.21108126e-03, -6.28151518e-03,  7.99737362e-02,
#          2.70717193e-02,  7.58708887e-02, -1.77060080e-04,
#         -2.19821119e-04, -1.58823696e-01, -1.89915904e-02,
#          8.44802590e-03, -1.57440564e-05,  5.21000966e-02,
#         -1.45293690e-01, -1.98132943e-02, -3.67688674e-03,
#          6.51966221e-03, -3.63324378e-07,  1.94819973e-01,
# ...

# %%
# 変数名とその係数を格納するDataFrameを作ります。
coeff_df = DataFrame([X_multi.columns, log_model.coef_[0]]).T

# %%
coeff_df

col_names = ['Features','Coefficient_Estimate']
coeff_df.columns=col_names

# %%
x_temp = coeff_df.Features
y_temp = coeff_df.Coefficient_Estimate

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.xticks(rotation=70)
plt.bar(x_temp, y_temp)
# Out:
# <BarContainer object of 25 artists>

# %%
print('切片の値は{}'.format(logreg.intercept_))
# Out:
# 切片の値は[ 4.91263710e-05 -9.03507997e-06 -4.61608931e-05]
